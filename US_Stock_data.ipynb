# %%
import pandas as pd
import FinanceDataReader as fdr
import numpy as np

# %%
df_sp500 = fdr.StockListing('sp500')
df_sp500
# Out:
#     Symbol                 Name                  Sector  \
# 0      MMM           3M Company             Industrials
# 1      ABT  Abbott Laboratories             Health Care
# 2     ABBV          AbbVie Inc.             Health Care
# 3     ABMD              Abiomed             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 500    YUM      Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
#                                Industry
# 0              Industrial Conglomerates
# 1                 Health Care Equipment
# 2                       Pharmaceuticals
# 3                 Health Care Equipment
# 4        IT Consulting & Other Services
# ..                                  ...
# ...

# %%
df_sp500.to_excel('./sp500.xlsx')

# %%
len(df_sp500)
# Out:
# 505

# %%
df = fdr.DataReader("AAPL", "1990", "2022")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7914 entries, 1990-01-02 to 2021-05-28
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   7914 non-null   float64
#  1   Open    7914 non-null   float64
#  2   High    7914 non-null   float64
#  3   Low     7914 non-null   float64
#  4   Volume  7914 non-null   float64
#  5   Change  7914 non-null   float64
# dtypes: float64(6)
# memory usage: 432.8 KB

# %%
df = fdr.DataReader("AAPL", "2018", "2021")
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = fdr.DataReader('US500', '2008')
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_sp500 = fdr.StockListing('sp500')
df_sp500.describe()
# Out:
#        Symbol     Name                  Sector               Industry
# count     505      505                     505                    505
# unique    505      505                      11                    124
# top       UAL  Hologic  Information Technology  Health Care Equipment
# freq        1        1                      74                     19

# %%
df_sp500['Symbol']
# Out:
# 0       MMM
# 1       ABT
# 2      ABBV
# 3      ABMD
# 4       ACN
#        ...
# 500     YUM
# 501    ZBRA
# 502     ZBH
# 503    ZION
# 504     ZTS
# Name: Symbol, Length: 505, dtype: object

# %%
df_sp500['Symbol'].to_dict()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/jiyoung/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Symbol', 'Name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-940fb1581c8b> in <module>
# ...

# %%
df_sp500['Name'].to_dict()
# Out:
# {0: '3M Company',
#  1: 'Abbott Laboratories',
#  2: 'AbbVie Inc.',
#  3: 'Abiomed',
#  4: 'Accenture',
#  5: 'Activision Blizzard',
#  6: 'Adobe Inc.',
#  7: 'Advanced Micro Devices',
#  8: 'Advance Auto Parts',
#  9: 'AES Corp',
#  10: 'Aflac',
#  11: 'Agilent Technologies',
#  12: 'Air Products & Chemicals',
#  13: 'Akamai Technologies',
#  14: 'Alaska Air Group',
#  15: 'Albemarle Corporation',
#  16: 'Alexandria Real Estate Equities',
#  17: 'Alexion Pharmaceuticals',
#  18: 'Align Technology',
#  19: 'Allegion',
#  20: 'Alliant Energy',
#  21: 'Allstate Corp',
#  22: 'Alphabet Inc. (Class A)',
#  23: 'Alphabet Inc. (Class C)',
#  24: 'Altria Group Inc',
#  25: 'Amazon.com Inc.',
#  26: 'Amcor plc',
#  27: 'Ameren Corp',
#  28: 'American Airlines Group',
#  29: 'American Electric Power',
#  30: 'American Express',
#  31: 'American International Group',
#  32: 'American Tower Corp.',
#  33: 'American Water Works',
#  34: 'Ameriprise Financial',
#  35: 'AmerisourceBergen',
# ...
