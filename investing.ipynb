# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0'}

URL = 'https://kr.investing.com/equities/apple-computer-inc-news'
response = requests.get(URL, headers=headers)
soup = BeautifulSoup(response.text)
response
# Out:
# <Response [200]>

# %%
url = "https://kr.investing.com/equities/apple-computer-inc-news"
headers = {"User-Agent" : "Mozilla/5.0 (Windows"}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [403]>

# %%
dom = BeautifulSoup(response.content, "html.parser")

# %%
dom
# Out:
#  <!DOCTYPE HTML>
#
# <html class="kr" dir="ltr" geo="KR" lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml" xmlns:schema="http://schema.org/">
# <head>
# <script type="text/javascript">
#     function OptanonWrapper() { }
#
#     // temp for checks
#     </script>
# <style>
# 	.ot-floating-button {
# 		z-index:12 !important;
# 	}
# </style>
# <script src="https://i-invdn-com.akamaized.net/js/jquery-6.4.9.04.min.js"></script>
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     </script>
# <script type="text/javascript">
#         window.helpers = {
# ...

# %%
a = dom.find_all(class_ = "textDiv")

# %%
apples = []
for i in range(len(a)):
    item = a[i]
    try : 
        text = item.select_one('.date').text
        date = re.findall('[0-9]{0,2} 시간 전',text)
    except:
        continue        
    title = item.select_one(".title").get("title")
    link = item.select_one(".title").get("href")
    if date != []:
        apples.append({'title':title, "link":link, 'date':date})

# %%
pd.DataFrame(apples)
# Out:
#                                          title  \
# 0  서학개미 벌써 200조 거래…테슬라 주춤하자 3배 레버리지ETF '베팅' 급증
# 1                             서학개미 올들어 200조 거래
# 2              삼성 TV 글로벌 점유율 최대…매출기준 1분기 32.9%
# 3      애플·테슬라 약세에…서학개미들 3배 수익률 노린 레버리지 상품 '베팅'
# 4             中정부 전폭적 지원 '니오(NIO)', 테슬라 견제 나서나
#
#                                      link       date
# 0            /news/economy/article-640625  [14 시간 전]
# 1            /news/economy/article-640575  [16 시간 전]
# 2            /news/economy/article-640545  [16 시간 전]
# 3            /news/economy/article-640528  [16 시간 전]
# 4  /news/stock-market-news/article-640480  [17 시간 전]

# %%
item = a[8]

# %%
item.select_one(".title").get("href")
# Out:
# 'https://invst.ly/uwwqf'

# %%
item.select_one(".title").get("title")
# Out:
# "애플-에픽, '앱수수료' 소송전 종료 임박…앱시장 판도 바뀔까"

# %%
text = item.select_one('.date').text

# %%
item
# Out:
# <div class="textDiv">
# <a class="js-external-link title" href="https://invst.ly/uwwqf" rel="nofollow" target="_blank" title="애플-에픽, '앱수수료' 소송전 종료 임박…앱시장 판도 바뀔까">애플-에픽, '앱수수료' 소송전 종료 임박…앱시장 판도 바뀔까</a>
# <div class="articleDetails"><span>부터 asiae</span><span class="date"> - 2021년 05월 24일</span></div>
# <p>애플과 에픽게임즈 간 앱수수료 정책을 둘러싼 반독점 소송전의 공판이 곧 마무리된다. 재판 결과에 따라 1700억달러(약 192조원)규모의 모바일 앱시장에서 애플을 비롯한 플랫폼 기...</p>
# </div>

# %%
import re

# %%
re.findall('[0-9]{0,2} 시간 전',text) == []
# Out:
# True

# %%
text.split("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ad9dc5e9be31> in <module>
# ----> 1 text.split("")
#
# ValueError: empty separator

# %%
text
# Out:
# '\xa0-\xa02021년 05월 24일'
